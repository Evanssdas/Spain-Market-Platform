# %% [markdown]
# # Spain Power Market Platform — Quick Start
# The reusable production logic is in `src/spain_power`. Use this notebook only for exploration.

# %%
from spain_power.config import load_config
config = load_config('../config.yaml')
config['project']
